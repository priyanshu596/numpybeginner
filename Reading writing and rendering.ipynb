# %% [markdown]
# # 1. Import Dependencies

# %%
import cv2
import os

# %% [markdown]
# # 2. read in Image

# %%
img_path = os.path.join('data','images','torch.jpeg')

# %%
img_path
# Out:
# 'data\\images\\torch.jpeg'

# %%
img_path

# %%
height , width, channel = img.shape

# %%
channel
# Out:
# 3

# %% [markdown]
# # 3.Render in image

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from matplotlib import pyplot as plt

# %%
#show image
plt.imshow(img)

# %%
recolor = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(grey)
plt.show()#get rid of the text above image

# %% [markdown]
# # 4. Write out image

# %%
cv2.imwrite('greyimage.jpeg', grey)
# Out:
# True

# %%
output_path = os.path.join('data','output','outputgrey.jpg')

# %%
cv2.imwrite(output_path, grey)
# Out:
# True
